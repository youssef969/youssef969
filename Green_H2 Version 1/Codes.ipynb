# %%
from tkinter import * 
from tkinter import messagebox 
from time import strftime
import datetime
import requests
import re

#259269
#31c48e
class Green:
    def __init__(self,root):
        self.root = root
        self.root.geometry("950x500+350+150")  # hight = 864   width = 1536
        self.root.resizable(True,True)
        self.root.config(bg="white")
        self.root.title("Weather")
        self.root.iconbitmap("C:\\Users\\Computec\\Downloads\\Icons\\weather-app.ico")
    
# =============================================== Weather API ==================================================
        api2 = "https://api.open-meteo.com/v1/forecast?latitude=31.037933&longitude=31.381523&current=wind_speed_10m&daily=temperature_2m_max,temperature_2m_min,sunrise,sunset,wind_speed_10m_max&timezone=Africa%2FCairo&forecast_days=14"
        json_data = requests.get(api2).json()
        self.current = json_data["daily"]['temperature_2m_max'][0]
        self.tempday1 = json_data['daily']['temperature_2m_max'][1]
        self.tempday2 = json_data['daily']['temperature_2m_max'][2]
        self.tempday3 = json_data['daily']['temperature_2m_max'][3]
        self.tempday4 = json_data['daily']['temperature_2m_max'][4]
        self.tempday5 = json_data['daily']['temperature_2m_max'][5]
        self.tempday6 = json_data['daily']['temperature_2m_max'][6]
        self.tempday7 = json_data['daily']['temperature_2m_max'][7]
        
        self.current_min = json_data["daily"]['temperature_2m_min'][0]
        self.tempday1_min = json_data['daily']['temperature_2m_min'][1]
        self.tempday2_min = json_data['daily']['temperature_2m_min'][2]
        self.tempday3_min = json_data['daily']['temperature_2m_min'][3]
        self.tempday4_min = json_data['daily']['temperature_2m_min'][4]
        self.tempday5_min = json_data['daily']['temperature_2m_min'][5]
        self.tempday6_min = json_data['daily']['temperature_2m_min'][6]
        self.tempday7_min = json_data['daily']['temperature_2m_min'][7]
        
        self.current_speed = json_data["daily"]["wind_speed_10m_max"][0]
        self.tempday1_speed = json_data['daily']["wind_speed_10m_max"][1]
        self.tempday2_speed = json_data['daily']["wind_speed_10m_max"][2]
        self.tempday3_speed = json_data['daily']["wind_speed_10m_max"][3]
        self.tempday4_speed = json_data['daily']["wind_speed_10m_max"][4]
        self.tempday5_speed = json_data['daily']["wind_speed_10m_max"][5]
        self.tempday6_speed = json_data['daily']["wind_speed_10m_max"][6]
        self.tempday7_speed = json_data['daily']["wind_speed_10m_max"][7]
        
        sunset = json_data["daily"]["sunset"][0]
        result1 = re.findall(r"[0-9]+:[0-9]+",sunset)
        self.sunset_1 = result1[0]
        
        sunrise = json_data["daily"]["sunrise"][0]
        result1 = re.findall(r"[0-9]+:[0-9]+",sunrise)
        self.sunrise_1 = result1[0]
        
        # ================================================= first_interface ========================================
        
        fr1 = Frame(self.root,bg="#27AE60")
        fr1.place(x=50,y=0,width=900,height=80)
       
        fr2 = Frame(self.root,bg="#7DCEA0")
        fr2.place(x=0,y=0,width=50,height=500)
        self.image = PhotoImage(file ="C:\\Users\\Computec\\Downloads\\PNG Icons\\1710162623466-removebg-preview.png")
        self.sub = self.image.subsample(5,5)
        image_label = Label(fr1,image=self.sub,bg="#27AE60")
        image_label.place(x=810,y=0)
        
        GreenH = Label(fr1,text="Green Hydorgen",fg="white",font=("Pacifico",19,"bold"),bg="#27AE60")
        GreenH.place(x=590,y=7)
        
        self.Home = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\home.png")
        self.sub_home = self.Home.subsample(5,5)
        Home_button = Button(fr2,image=self.sub_home,bd=0,bg="#7DCEA0",justify="center",activebackground="#7DCEA0",command=self.home)
        Home_button.place(x=10,y=20,width=30,height=60)
        
        
        
        self.weather = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\rainy-day.png")
        self.sub_weather = self.weather.subsample(5,5)
        weather_button_1 =  Button(fr2,image=self.sub_weather,bd=0,bg="#7DCEA0",justify="center",activebackground="#7DCEA0")
        weather_button_1.place(x=10,y=80,width=30,height=60)
        
        self.monitor = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\reading.png")
        self.sub_monitor = self.monitor.subsample(5,5)
        Monitor_button =  Button(fr2,image=self.sub_monitor,bd=0,bg="#7DCEA0",justify="center",activebackground="#7DCEA0")
        Monitor_button.place(x=10,y=140,width=30,height=60)
        
        self.Settings = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\gear.png")
        self.sub_Settings = self.Settings.subsample(5,5)
        Settings_button = Button(fr2,image=self.sub_Settings,bd=0,bg="#7DCEA0",justify="center",activebackground="#7DCEA0")
        Settings_button.place(x=10,y=200,width=30,height=60)
        
        self.Exit = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\logout.png")
        self.sub_Exit = self.Exit.subsample(5,5)
        Exit_button = Button(fr2,image=self.sub_Exit,bd=0,bg="#7DCEA0",justify="center",activebackground="#7DCEA0",command=self.Exit_func )
        Exit_button.place(x=13,y=260,width=30,height=65)
        
    
        # ============================================ Frame ======================================================

        f1 = Frame(self.root,bg="white",highlightbackground="Black",highlightthickness=3)
        f1.place(x=50,y=100,width=220,height=190)

        f2 = Frame(self.root,bg="white",width=900,height=200)
        f2.place(x=50,y=300)
        
       
        # firstframe = Frame(f2,bg="white",width=200,height=130)
        # firstframe.place(x=43,y=40)

        #=============================================================== photo Image =====================================================
        # ========================================= Search Bar ==============================================
        # self.search_bar = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\Copy of search.png")
        # self.sub_search = self.search_bar.subsample(2,2)
        # Search_label = Label(self.root,image=self.sub_search,background="#57aeff",)
        # Search_label.place(x=350,y=10) #60
        # Entry_city = Entry(self.root,bd=0,justify="center",font=("Arial",14,"bold"),bg="#1f3243",fg="White",cursor="hand2",textvariable=self.City_name)
        # Entry_city.place(x=380,y=20,height=25,width=160) #90

        # ======================================= Search Icon =================================================
        # self.Search_icon = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\search.png")
        # self.sub_search_icon = self.Search_icon.subsample(3,3)
        # Search_button = Button(self.root,image=self.sub_search_icon,bg="#1f3243",fg="white",bd=0,activebackground="#1f3243",cursor="hand2",command=self.home)
        # Search_button.place(x=545,y=20)   #255

        self.box = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\rectangle.png")
        self.sub_box = self.box.subsample(1,1)
        box_label = Label(f2,image=self.sub_box,bg="#1f3243")
        box_label.place(x=15,y=10)

        self.cloud = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\cloudy.png")
        self.sub_cloud = self.cloud.subsample(3,3)
        cloud_label = Label(self.root,image=self.sub_cloud,bg="white")
        cloud_label.place(x=350,y=80)

        self.box1 = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\rounded-rectangle.png")
        box1_label = Label(f2,image=self.box1,bg="#1f3243")
        box1_label.place(x=280,y=30)

        self.box2 = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\rounded-rectangle.png")
        box2_label = Label(f2,image=self.box2,bg="#1f3243")
        box2_label.place(x=380,y=30)

        self.box3 = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\rounded-rectangle.png")
        box3_label = Label(f2,image=self.box3,bg="#1f3243")
        box3_label.place(x=480,y=30)

        self.box4 = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\rounded-rectangle.png")
        box4_label = Label(f2,image=self.box4,bg="#1f3243")
        box4_label.place(x=580,y=30)

        self.box5 = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\rounded-rectangle.png")
        box5_label = Label(f2,image=self.box5,bg="#1f3243")
        box5_label.place(x=680,y=30)

        self.box6 = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\rounded-rectangle.png")
        box6_label = Label(f2,image=self.box6,bg="#1f3243")
        box6_label.place(x=780,y=30)


        # ================================================= Labels =======================================================  
        # hist_lbl = Label(self.root,font=('calibri',20,'bold'),foreground="white",bg="#57aeff")
        # hist_lbl.place(x=750,y=5)
        # date_lbl = Label(self.root,font = ('calibri',20,'bold'),foreground = 'white',bg="#57aeff")
        # date_lbl.place(x=20,y=5)

        City = Label(self.root,text="Egypt \ AL Dakahlia",font=('Stincil',30,'bold'),foreground="white",bg="#57aeff")
        City.place(x=560,y=100)
        
        Max_temp_lbl = Label(f1,text=f"Max Temp.             {int(self.current)} ℃",font=('Arialblack',10,'bold'),fg="black",bg="white")
        Max_temp_lbl.place(x=20,y=5)
       
        Min_temp_lbl = Label(f1,text=f"Min Temp.              {self.current_min} ℃",font=('Arialblack',10,'bold'),fg="black",bg="white")
        Min_temp_lbl.place(x=20,y=35)

        windspeed_lbl = Label(f1,text=f"Wind Speed         {self.current_speed} K\M",font=('Arialblack',10,'bold'),fg="black",bg="white")
        windspeed_lbl.place(x=20,y=65)
        
        sunrise_lbl = Label(f1,text=f"Sunrise                    {self.sunrise_1}",font=('Arialblack',10,'bold'),fg="black",bg="white")
        sunrise_lbl.place(x=20,y=95)

        sunrset_lbl = Label(f1,text=f"Sunset                     {self.sunset_1}",font=('Arialblack',10,'bold'),fg="black",bg="white")
        sunrset_lbl.place(x=20,y=125)

        # ======================================================== Bottem Frame =================================================
        current_day = datetime.datetime.now()
        current_day_lbl = Label(self.root,text=current_day.strftime("%A"),font=("Arial",15,"bold"),bg="#1f3243",fg="white")
        current_day_lbl.place(x=800,y=180)
        
        text_1 = f"""Max Temp. = {self.tempday1} ℃\nMin Temp. = {self.tempday1_min} ℃\nWind speed = {self.tempday1_speed} K\M"""
        first_day = current_day + datetime.timedelta(1)
        fr_day1 = Frame(f2,bg="#1f3243",width=400,height=200)
        fr_day1.place(x=35,y=27,width=215,height=140)
        first_day_lbl = Label(fr_day1,text=first_day.strftime("%A"),font=("Arial",20,"bold"),bg="#1f3243",fg="white")
        first_day_lbl.pack(fill=X)
        lbl_1 = Label(fr_day1,text=text_1,font=("Arial",14,"bold"),bg="#1f3243",fg="white")
        lbl_1.pack()

        text_2 = f"""Max Temp = {int(self.tempday2)}℃ \n\n\n Min Temp = {int(self.tempday2_min)}℃\n\n\nWind = {int(self.tempday2_speed)}K\M"""
        second_day = first_day + datetime.timedelta(1)
        fr_day2 = Frame(f2,bg="#1f3243",width=400,height=200)
        fr_day2.place(x=295,y=45,width=60,height=100)
        first_day_lbl = Label(fr_day2,text=second_day.strftime("%A"),font=("Arial",7,"bold"),bg="#1f3243",fg="white")
        first_day_lbl.pack(fill=X)
        lbl_2 = Label(fr_day2,text=text_2,font=("Arial",6,"bold"),bg="#1f3243",fg="white")
        lbl_2.pack()
        
        text_3 = f"Max Temp = {int(self.tempday3)}℃ \n\n\n Min Temp = {int(self.tempday3_min)}℃\n\n\nWind = {int(self.tempday3_speed)}K\M"
        third_day = second_day + datetime.timedelta(1)
        fr_day3 = Frame(f2,bg="#1f3243",width=400,height=200)
        fr_day3.place(x=395,y=45,width=60,height=100)
        third_day_lbl = Label(fr_day3,text=third_day.strftime("%A"),font=("Arial",7,"bold"),bg="#1f3243",fg="white")
        third_day_lbl.pack(fill=X)
        lbl_3 = Label(fr_day3,text=text_3,font=("Arial",6,"bold"),bg="#1f3243",fg="white")
        lbl_3.pack()
        
        text_4 = f"Max Temp = {int(self.tempday3)}℃ \n\n\n Min Temp = {int(self.tempday3_min)}℃\n\n\nWind = {int(self.tempday3_speed)}K\M"
        fourth_day = third_day + datetime.timedelta(1)
        fr_day4 = Frame(f2,bg="#1f3243",width=400,height=200)
        fr_day4.place(x=495,y=45,width=60,height=100)
        fourth_day_lbl = Label(fr_day4,text=fourth_day.strftime("%A"),font=("Arial",7,"bold"),bg="#1f3243",fg="white")
        fourth_day_lbl.pack(fill=X)
        lbl_4 = Label(fr_day4,text=text_4,font=("Arial",6,"bold"),bg="#1f3243",fg="white")
        lbl_4.pack()

        fifth_day = fourth_day + datetime.timedelta(1)
        fr_day5 = Frame(f2,bg="#1f3243",width=400,height=200)
        fr_day5.place(x=595,y=45,width=60,height=100)
        fifth_day_lbl = Label(fr_day5,text=fifth_day.strftime("%A"),font=("Arial",7,"bold"),bg="#1f3243",fg="white")
        fifth_day_lbl.pack(fill=X)

        sixth_day = fifth_day + datetime.timedelta(1)
        fr_day6 = Frame(f2,bg="#1f3243",width=400,height=200)
        fr_day6.place(x=695,y=45,width=60,height=100)
        sixth_day_lbl = Label(fr_day6,text=sixth_day.strftime("%A"),font=("Arial",7,"bold"),bg="#1f3243",fg="white")
        sixth_day_lbl.pack(fill=X)

        last_day = sixth_day + datetime.timedelta(1)
        fr_day6 = Frame(f2,bg="#1f3243",width=400,height=200)
        fr_day6.place(x=795,y=45,width=60,height=100)
        last_day_lbl = Label(fr_day6,text=last_day.strftime("%A"),font=("Arial",8,"bold"),bg="#1f3243",fg="white")
        last_day_lbl.pack(fill=X)
        

    def time_now(self):
        self.date = strftime('%I:%M:%S %p')
        self.date_lbl.config(text = self.date)
        self.date_lbl.after(1000,self.time_now())
            
    def history(self):
        hist =  strftime("%d/%m/%Y")
        self.hist_lbl.config(text=hist)
        self.hist_lbl.after(1000,self.history())

    def Search(self):
        self.city = self.City_name.get()
        city_cap = self.city.capitalize()
        f3 = Frame(self.root,bg="#57aeff",width=400,height=200)
        f3.place(x=500,y=100)
        City_lbl = Label(f3,text=f"{city_cap}",font=('Arialblack',40,'bold'),fg="white",bg="#57aeff")
        City_lbl.place(x=0,y=0)
        self.City_name.set("")  
    
    def home(self):
        self.root.destroy()
        from First_interface import Into
        
        
    def Exit_func(self):
        self.ques =  messagebox.askyesno("EXIT","Do you really want to Exit")
        if self.ques == 1:
            self.root.destroy()
        else: 
            return     
root = Tk()       
ob = Green(root)
root.mainloop()

# %%
from tkinter import * 
from tkinter import messagebox
from time import strftime
import speech_recognition as sr
import sys
import re
import threading 

class Into:
    def __init__(self,root1):
        self.root1 = root1
        self.root1.geometry("900x500+350+150")
        self.root1.resizable(True,True)
        self.root1.config(bg="white")
        self.root1.title("Green Hydrogen")
        self.root1.iconbitmap("C:\\Users\\Computec\\Downloads\\Icons\\1710162623466-removebg-preview.ico")
        
        # ================================================== Frames ============================================================
        fr1 = Frame(self.root1,bg="#27AE60")
        fr1.place(x=90,y=0,width=800,height=60)
       
        fr2 = Frame(self.root1,bg="#7DCEA0")
        fr2.place(x=0,y=0,width=50,height=500)
        
        fr3 = Frame(self.root1,bg="#27AE60")
        fr3.place(x=50,y=125,width=850,height=5)
        
        # ================================================== Variables ========================================================
        self.text1 = StringVar()
        self.text2 = StringVar()
        self.text2.set("")
        # =================================================== Frame 1 =====================================================
        
        self.image = PhotoImage(file ="C:\\Users\\Computec\\Downloads\\PNG Icons\\YY2.png")
        self.sub = self.image.subsample(20,20)
        image_label = Label(self.root1,image=self.sub,bg="white")
        image_label.place(x=100,y=0)
        
        GreenH = Label(self.root1,text="Green Hydorgen",fg="white",font=("Pacifico",19,"bold"),bg="#27AE60")
        GreenH.place(x=540,y=7)
        
       
        
        # self.image = PhotoImage(file ="C:\\Users\\Computec\\Downloads\\PNG Icons\\Green.png")
        # self.sub = self.image.subsample(1,1)
        # image_label = Label(self.root1,image=self.sub,bg="#27AE60")
        # image_label.place(x=50,y=0)  
        
        
        # ==================================================== Root =======================================================
        self.Search_bar = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\Copy of search.png")
        self.sub_search_bar = self.Search_bar.subsample(2,2)
        search_bar = Label(self.root1,image=self.sub_search_bar,bg="white")
        search_bar.place(x=350,y=80)
        
        self.Search = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\magnifying-glass.png")
        self.Sub_Search = self.Search.subsample(5,5)
        search = Button(self.root1,image=self.Sub_Search,bg="#434343",bd=0,activebackground="#434343",cursor="hand2",command=self.search)
        search.place(x=544,y=87)
        
        self.voice = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\microphone.png")
        self.sub_voice = self.voice.subsample(5,5)
        voice = Button(self.root1,image=self.sub_voice,bg="#434343",bd=0,activebackground="#434343",cursor="hand2",command=self.NLP)
        voice.place(x=370,y=87)
        
        self.search_entry = Entry(self.root1,bd=0,justify="center",font=("Arial",10,"bold"),bg="#434343",fg="White",cursor="hand2",textvariable=self.text1,insertbackground="White")
        self.search_entry.place(x=395,y=87,width=145,height=29)
        
       
        
        # ===================================================== Frame 2 ====================================================
        
        self.Home = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\home 2.png")
        self.sub_home = self.Home.subsample(5,5)
        Home_button = Button(fr2,image=self.sub_home,bd=0,bg="#7DCEA0",justify="center",activebackground="#7DCEA0")
        Home_button.place(x=10,y=20,width=30,height=60)
        
        
        
        self.weather = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\rainy-day.png")
        self.sub_weather = self.weather.subsample(5,5)
        Weather_button =  Button(fr2,image=self.sub_weather,bd=0,bg="#7DCEA0",justify="center",activebackground="#7DCEA0",command=self.Weather)
        Weather_button.place(x=10,y=80,width=30,height=60)
        
        self.monitor = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\reading.png")
        self.sub_monitor = self.monitor.subsample(5,5)
        Monitor_button =  Button(fr2,image=self.sub_monitor,bd=0,bg="#7DCEA0",justify="center",activebackground="#7DCEA0")
        Monitor_button.place(x=10,y=140,width=30,height=60)
        
        self.Settings = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\gear.png")
        self.sub_Settings = self.Settings.subsample(5,5)
        Settings_button = Button(fr2,image=self.sub_Settings,bd=0,bg="#7DCEA0",justify="center",activebackground="#7DCEA0")
        Settings_button.place(x=10,y=200,width=30,height=60)
        
        self.Exit = PhotoImage(file="C:\\Users\\Computec\\Downloads\\PNG Icons\\logout.png")
        self.sub_Exit = self.Exit.subsample(5,5)
        Exit_button = Button(fr2,image=self.sub_Exit,bd=0,bg="#7DCEA0",justify="center",activebackground="#7DCEA0",command=self.Exit_func)
        Exit_button.place(x=13,y=260,width=30,height=65)
        
        # hist_lbl = Label(root1,font=('calibri',20,'bold'),foreground="white",bg="#57aeff")
        # hist_lbl.place(x=750,y=5)
        
        # date_lbl = Label(root1,font =('calibri',20,'bold'),foreground = 'white',bg="#57aeff")
        # date_lbl.place(x=20,y=5)
        
    
    def time(self):
            date = strftime('%I:%M:%S %p')
            self.date_lbl.config(text= date)
            self.date_lbl.after(1000,self.time())
            
    def history(self):
        hist =  strftime("%d/%m/%Y")
        self.hist_lbl.config(text=hist)
        self.hist_lbl.after(1000,self.history())
            
    def NLP(self):
            rec = sr.Recognizer()                       # للتعرف على الصوت 
            with sr.Microphone() as src:                # المكان الي هتستقبل منه الصوت علشان تتعرف عليه
                self.text1.set("Hello")
                print("say something.......")
                while True:
                    root1.update()
                    self.audio = rec.listen(src)                     # هتستقبل الصوت من المايك
                    self.text = rec.recognize_google(self.audio)          # هنستخدم معرف جوجل علشان يتعؤف على الصوت
                    
                    result = re.findall(r"[Tt]emp\w+|[Hh]um\w+|[Ww]ind\s[Ss]peed|[Cc]lose",self.text)
                    temp = re.findall(r"[Tt]emp\w+",self.text)
                    temp.append("")
                    humidity = re.findall(r"[Hh]um\w+",self.text)
                    humidity.append("")
                    wind = re.findall(r"[Ww]ind\s[Ss]peed",self.text)
                    wind.append("")
                    close = re.findall(r"[Cc]lose",self.text)
                    close.append("")
                    
                    print(self.text)
                
                    for x in range(len(result)):
                        
                            if temp[0] == result[x] :
                                self.text1.set("Temperature now is : 25")
                                print("temperature now is : 25") 
                                
                            elif humidity[0] == result[x]:
                                print("the humuidity now: 25")
                                self.text1.set("humuidity now is : 20")
                               
                            elif wind[0] == result[x]:
                                print("Wind speed is 60 K\M")
                                self.text1.set("Wind speed is 60 K\M")
                            elif close[0] == result[x]:
                                    self.root1.destroy()
                                    sys.exit()
                            else: 
                                print("False")
                                
    def search(self):
        self.text = self.text1.get()
        result = re.findall(r"[Tt]emp\w+|[Hh]um\w+|[Ww]ind\[Ss]peed|[Cc]lose",self.text)
        temp = re.findall(r"[Tt]emp\w+",self.text)
        temp.append("")
        humidity = re.findall(r"[Hh]um\w+",self.text)
        humidity.append("")
        wind = re.findall(r"[Ww]ind\[Ss]peed",self.text)
        wind.append("")
        close = re.findall(r"[Cc]lose",self.text)
        close.append("")
        if self.text1.get() =="":
                
                self.text2.set("")
                
        for x in range(len(result)):
           
                if temp[0] == result[x]:
                    
                    label_1 = Entry(self.root1,bg="white",fg="black",bd=0,textvariable=self.text2)
                    label_1.place(x=500,y=300)
                    self.text2.set("Temperature now is : 25")
                                    
                elif humidity[0] == result[x]:
                    label_1 = Entry(self.root1,bg="white",fg="black",bd=0,textvariable=self.text2)
                    label_1.place(x=500,y=300)
                    self.text2.set("the humuidity now: 25")
                               
                elif wind[0] == result[x]:
                    label_1 = Entry(self.root1,bg="white",fg="black",bd=0,textvariable=self.text2)
                    label_1.place(x=500,y=300)
                    self.text2.set("Wind speed is 60 K\M")
                   
                elif close[0] == result[x]:
                        self.root1.destroy()
                        sys.exit()
                           
                else: 
                    print("False")  
                    
    def Weather (self):
        self.root1.destroy()
        from Weather import Green
        sys.exit()
        
    def Exit_func(self):
        self.ques =  messagebox.askyesno("EXIT","Do you really want to Exit")
        if self.ques == 1:
            self.root1.destroy()
        else: 
            return
        
        
root1 = Tk()
ob = Into(root1)
root1.mainloop()

# %%
from tkinter import * 
from PIL import Image ,ImageTk
import threading 
import warnings 


gif_frames =[]
frame_delay = 0
frame_count = -1

def read_gif():
    global frame_delay
    gif_file = Image.open("D:\\My Download\\WhatsApp-Video-2024-03-18-at-01.17.27_21aadb2d.gif") # 101 frames
    for r in range(0,gif_file.n_frames):
        gif_file.seek(r)
        gif_frames.append(gif_file.copy())
    frame_delay = gif_file.info["duration"]
    play_gif()
       
def play_gif():
    global frame_count , current_frame
    if frame_count >= len(gif_frames)- 1:
        frame_count = -1
    else:
        frame_count +=1
        current_frame = ImageTk.PhotoImage(gif_frames[frame_count])
        gif_label.config(image=current_frame)
        root.after(frame_delay,play_gif)

def load():
    read_gif()
    play_gif()
    root.destroy()
    from First_interface import Into      


root = Tk()
root.geometry("640x432")
root.after(3000,load)
image = PhotoImage(file = "C:\\Users\\Computec\\Downloads\\PNG Icons\\1710162623466-removebg-preview.png")
sub = image.subsample(2,2)

image_label = Label(root,image=sub,bg="white")
image_label.pack()  

GreenH_label = Label(text="Green Hydrogeen",bg="white",font=("Pacifico",18,"bold"),fg="#369f31") 
GreenH_label.pack() 

gif_label = Label(root)
gif_label.pack(fill=BOTH)
threading.Thread(target=read_gif).start()

root.mainloop()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
